# %% [markdown]
# <h1> Matplotlib </h1>
#
# - Matplotlib is the most popular plotting library for Python.
# - It gives you control over every aspect of a figure.
# - It was designed to have a similar feel to MatLab's graphical plotting.

# %% [markdown]
# You'll need to install it with pip or conda at your command line or terminal with:
#
# ```conda install matplotlib```<br>
# or<br>
# ```pip install matplotlib```

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
X = np.linspace(0, 5, 11)
y = X  ** 2

# %%
X
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %% [markdown]
# <b> Functional Method to plot </b>

# %%
plt.plot(X, y, "g-")

# %%
plt.subplot(1,2,1)
plt.plot(X,y)

plt.subplot(1,2,2)
plt.plot(y,X)

# %% [markdown]
# <b> Object Oriented Approach </b>

# %%
fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(X,y)
axes.set_xlabel("X Label")
axes.set_ylabel("Y Label")
axes.set_title("Set Title")
# Out:
# Text(0.5, 1.0, 'Set Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
#axes2 = fig.add_axes([0.2,0.5,0.4,0.3])
#axes3 = fig.add_axes([0.5,0.5,0.3,0.3])
#axes4 = fig.add_axes([0.1,0.6,0.4,0.3])
#axes5 = fig.add_axes([0.5,0.1,0.4,0.3])

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes1.plot(X,y,"r-")
axes1.set_title("LARGER PLOT")
axes1.set_xlabel("X label")

axes2 = fig.add_axes([0.2,0.5,0.4,0.3])
axes2.plot(y,X,"b.")
axes2.set_title("SMALLER PLOT")
# Out:
# Text(0.5, 1.0, 'SMALLER PLOT')

# %%
fig

# %%
fig, axes = plt.subplots(nrows=3, ncols=3)
#plt.tight_layout()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

# %%
len(axes)
# Out:
# 2

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
for cur_ax in axes:
    cur_ax.plot(X,y)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

axes[0].plot(X,y)
axes[0].set_title("First Plot")

axes[1].plot(y,X)
axes[0].set_title("Second Plot")
# Out:
# Text(0.5, 1.0, 'Second Plot')

# %% [markdown]
# <h2> Figure Size and DPI </h2>

# %%
fig = plt.figure(figsize=(4,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(X,y)

# %%
fig = plt.figure(figsize=(2,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(X,y)

# %%
# figsize inche
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(8,2))

axes[0].plot(X,y)

axes[1].plot(y,X)

# %%
fig.savefig("my_plt.jpeg", dpi=200)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(X,y)
ax.set_title("Hello You")
ax.set_xlabel("X Label")
ax.set_ylabel("y Label")
# Out:
# Text(0, 0.5, 'y Label')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(X,X**2, label="X Squared")
ax.plot(X,X**4, label="X Cubed")

ax.legend(loc=0)
#ax.legend(loc=(0.1,0.1))

# %% [markdown]
# <h2> Plot Appearance </h2>

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
X = np.linspace(0,1,20)
y = np.sin(X)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(X,y, color="#FF8C00", linewidth=3, alpha=0.5, marker="o", markersize=20,
       markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green") # RGB Hex Code

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(X,y, color="#FF8C00", linewidth=0, marker="+", markersize=10, markerfacecolor="black") # RGB Hex Code

# %% [markdown]
# <h2> Line and Marker styles </h2>
#
# To change the line width, we can use the linewidth or lw keyword argument. The
# line style can be selected using the linestyle or ls keyword arguments.

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(X, X+1, color="red", linewidth=0.25)
ax.plot(X, X+2, color="red", linewidth=0.50)
ax.plot(X, X+3, color="red", linewidth=1.00)
ax.plot(X, X+4, color="red", linewidth=2.00)

# possible linestyle options "-", "-.", ":", "steps"
ax.plot(X, X+5, color="green", lw=3, linestyle="-")
ax.plot(X, X+6, color="green", lw=3, ls="-.")
ax.plot(X, X+7, color="green", lw=3, ls=":")

# custom dash
line, = ax.plot(X, X+8, color="black", lw=1.50)
line.set_dashes([5,10,15,10]) # format:line length, space length,..

# possible marker symbols: marker = "+", "o", "*", "s", ",", ".", "1", "2", "3", "4"
ax.plot(X, X+9, color="blue", lw=3, ls="-", marker="+")
ax.plot(X, X+10, color="blue", lw=3, ls="--", marker="o")
ax.plot(X, X+11, color="blue", lw=3, ls="-", marker="s")
ax.plot(X, X+12, color="blue", lw=3, ls="--", marker="1")

# marker size and color
ax.plot(X, X+13, color="purple", lw=1, ls="-", marker="o", markersize=2)
ax.plot(X, X+14, color="purple", lw=1, ls="-", marker="o", markersize=4)
ax.plot(X, X+15, color="purple", lw=1, ls="-", marker="o", markersize=8, markerfacecolor="black")
ax.plot(X, X+15, color="purple", lw=1, ls="-", marker="o", markersize=8,
       markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %%
plt.plot(X, X+13, color="purple", lw=1, ls="--")
plt.xlim([0,1])
plt.ylim([9,14])
# Out:
# (9.0, 14.0)

# %%
from random import sample
data = sample(range(1, 1000), 100)
plt.hist(data)
# Out:
# (array([11., 16.,  8., 11.,  8.,  8., 10.,  8., 11.,  9.]),
#  array([  3. , 100.8, 198.6, 296.4, 394.2, 492. , 589.8, 687.6, 785.4,
#         883.2, 981. ]),
#  <BarContainer object of 10 artists>)

# %%
data = [np.random.normal(0, std, 100) for std in range(1,4)]
plt.boxplot(data, vert=True, patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22d19c90fd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22d19af7b80>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x22d19c90c10>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x22d19af7460>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x22d19af7b20>,
# ...
#  'means': []}
